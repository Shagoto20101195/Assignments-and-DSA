# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io, img_as_float

# %%
I = io.imread('/content/triplet.jpg')
plt.figure(figsize=(5,5))
io.imshow(I)
plt.axis('off')
# Out:
# (-0.5, 446.5, 357.5, -0.5)

# %%
red = I[:,:,0]
io.imshow(red)
plt.axis('off')
# Out:
# (-0.5, 446.5, 357.5, -0.5)

# %%
green = I[:,:,1]
io.imshow(green)
plt.axis('off')
# Out:
# (-0.5, 446.5, 357.5, -0.5)

# %%
blue = I[:,:,2]
io.imshow(blue)
plt.axis('off')
# Out:
# (-0.5, 446.5, 357.5, -0.5)

# %%
# Contrast - A differnce in range
# e.g. 0.3 ~ 0.8 i.e. 0.8 - 0.3 = 0.5
# If added or subtracted, contrast remains the same but intesntiy changes
# If multiplied or divided, then contrast changes

# %%
# subplot - (row, col, plot figure in this slot)
# In same figure, we are drawing more slot

# %%
# In histogram, x-axis: intesity level and y-axis: pixel count
# In contrast stretching, pull lower value to 0 and and higher value to 1

# %%
# I.stretched = C1 * (I - C2). Here C2 = Low value and C1 = (High Target - Low Target) / (Contrast)

# %%
# The image being read is 8 bit
# Which is normalized by dividing by 255

# %%
# Need to be clipped for negative values to zero and numbers greater than 1 to 1

# %%
# Number of beans = intesity levels
# expose.histogram(image, nbins=256, normalize) -> if normalize = true then y will be from 0 to 1
# plt.twinx() -> twin axis

# %%
# Log transformation: 
# xaxis: input intensity levels
# yaxis: output intesnity levels
# Dark pixels being mapped to broader y (become brighter)
# Bright pixels being mapped to broader x (become darker)
# I_new = log(1 + K*I)

# %%
# Gamma transformation
# r = gamma
# I_new = I^r
# r < 1
# r = 1
# r > 1 -> more dakrer

# %%
# White background + Black Object = Better to detect

# %%
# Bit plane slicing / threshold
# Used to produce binary image
# Which portion to be darker or brighter
